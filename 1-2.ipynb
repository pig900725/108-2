# %% [markdown]
# ### 簡易畫圖

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.linspace(0,33,74)
sinus=np.sin(x)
cosinus=np.cos(x)
plt.plot(x,sinus,'r-o',x,cosinus,'g--')
plt.show()
